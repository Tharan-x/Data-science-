# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharan-x/Data-science-/blob/main/gold_prediction_project_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
pip install yfinance

# %%
usd_inr=yf.download('USDINR=X',start = '2024-0101', end='2024-12-31', interval='1wk')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['USDINR=X']: ValueError("time data '2024-0101' does not match format '%Y-%m-%d'")

# %%
usd_inr.head()
# Out:
# Empty DataFrame
# Columns: [(Adj Close, USDINR=X), (Close, USDINR=X), (High, USDINR=X), (Low, USDINR=X), (Open, USDINR=X), (Volume, USDINR=X)]
# Index: []

# %%
import yfinance as yf

# %%
usd_inr=yf.download('USDINR=X',start = '2024-01-01', end='2024-12-31', interval='1wk')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
usd_inr.head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       USDINR=X   USDINR=X   USDINR=X   USDINR=X USDINR=X
# Date
# 2024-01-01  83.240601  83.360298  83.035004  83.248596        0
# 2024-01-08  83.076103  83.189697  82.779099  83.191101        0
# 2024-01-15  83.160599  83.230797  82.809998  82.872101        0
# 2024-01-22  83.146103  83.222504  81.513702  83.124702        0
# 2024-01-29  82.927597  83.212601  82.815002  83.121300        0

# %%
usd_inr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53 entries, 2024-01-01 to 2024-12-30
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, USDINR=X)   53 non-null     float64
#  1   (High, USDINR=X)    53 non-null     float64
#  2   (Low, USDINR=X)     53 non-null     float64
#  3   (Open, USDINR=X)    53 non-null     float64
#  4   (Volume, USDINR=X)  53 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.5 KB

# %%
usd_inr.reset_index(inplace=True)

# %%
usd_inr.head()
# Out:
# Price  index       Date      Close       High        Low       Open   Volume
# Ticker                    USDINR=X   USDINR=X   USDINR=X   USDINR=X USDINR=X
# 0          0 2024-01-01  83.240601  83.360298  83.035004  83.248596        0
# 1          1 2024-01-08  83.076103  83.189697  82.779099  83.191101        0
# 2          2 2024-01-15  83.160599  83.230797  82.809998  82.872101        0
# 3          3 2024-01-22  83.146103  83.222504  81.513702  83.124702        0
# 4          4 2024-01-29  82.927597  83.212601  82.815002  83.121300        0

# %%
usd_inr=usd_inr[['Date','Close']]
usd_inr.columns=['Date','USDINR']

# %%
import pandas as pd
import pandas as pd
from google.colab import files
uploaded = files.upload()
gold_dataset=pd.read_csv("1744865041406_Gold vs USDINR.csv")
gold_dataset.head()
# Out:
#      <input type="file" id="files-db5a0470-7a4a-43fe-9092-fb30fa53df6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db5a0470-7a4a-43fe-9092-fb30fa53df6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gold_dataset.head()
# Out:
#          Date    USD_INR     Goldrate
# 0  2024-01-01  83.240601  â¹5,066.31
# 1  2024-01-08  83.076103  â¹4,966.31
# 2  2024-01-15  83.160599  â¹5,015.33
# 3  2024-01-22  83.146103  â¹4,950.84
# 4  2024-01-29  82.927597  â¹4,976.77

# %%
gold_dataset['Gldrate']=gold_dataset['Goldrate'].replace('â¹','',regex=True).replace(',','',regex=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(gold_dataset)
plt.show()

# %%
sns.boxplot(gold_dataset)
plt.show()

# %%
gold_dataset['Goldrate']= pd.to_numeric(gold_dataset['Goldrate'])
sns.regplot(x='USA_INR',y='Goldrate',data=gold_dataset)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "â¹5,066.31"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-d06f2100b415> in <cell line: 0>()
# ----> 1 gold_dataset['Goldrate']= pd.to_numeric(gold_dataset['Goldrate'])
#       2 sns.regplot(x='USA_INR',y='Goldrate',data=gold_dataset)
#       3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     230         coerce_numeric = errors not in ("ignore", "raise")
#     231         try:
# --> 232             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233                 values,
# ...

# %%
x=gold_dataset['USD_INR']
y=gold_dataset['Goldrate']

# %%
x
# Out:
# 0     83.240601
# 1     83.076103
# 2     83.160599
# 3     83.146103
# 4     82.927597
# 5     82.985298
# 6     83.009598
# 7     82.872299
# 8     82.910400
# 9     82.752296
# 10    82.965599
# 11    83.226601
# 12    83.392998
# 13    83.477798
# 14    83.349297
# 15    83.544998
# 16    83.301804
# 17    83.406303
# 18    83.459396
# 19    83.470100
# 20    83.286400
# 21    83.320900
# 22    83.473099
# 23    83.522102
# 24    83.601601
# 25    83.450897
# 26    83.493401
# 27    83.518501
# 28    83.674301
# 29    83.744400
# 30    83.743896
# 31    83.988998
# 32    83.948303
# 33    83.940598
# 34    83.895103
# 35    83.983597
# 36    83.934799
# 37    83.614700
# 38    83.617104
# 39    84.009399
# 40    83.945999
# 41    84.053802
# 42    84.081802
# 43    84.091499
# 44    84.306396
# 45    84.473801
# 46    84.488297
# 47    84.556999
# 48    84.666000
# 49    84.802002
# 50    84.945000
# 51    85.386002
# 52    85.786598
# Name: USD_INR, dtype: float64

# %%
y
# Out:
# 0     â¹5,066.31
# 1     â¹4,966.31
# 2     â¹5,015.33
# 3     â¹4,950.84
# 4     â¹4,976.77
# 5     â¹4,953.90
# 6     â¹4,938.73
# 7     â¹4,934.99
# 8     â¹4,960.54
# 9     â¹5,167.64
# 10    â¹5,326.46
# 11    â¹5,283.44
# 12    â¹5,341.21
# 13    â¹5,543.85
# 14    â¹5,737.21
# 15    â¹5,874.86
# 16    â¹5,720.10
# 17    â¹5,744.34
# 18    â¹5,724.77
# 19    â¹5,754.39
# 20    â¹5,966.34
# 21    â¹5,765.04
# 22    â¹5,757.16
# 23    â¹5,691.70
# 24    â¹5,710.88
# 25    â¹5,738.99
# 26    â¹5,734.29
# 27    â¹5,803.07
# 28    â¹5,964.96
# 29    â¹5,909.38
# 30    â¹5,883.33
# 31    â¹5,967.66
# 32    â¹6,114.39
# 33    â¹6,182.13
# 34    â¹6,222.57
# 35    â¹6,179.61
# 36    â¹6,201.84
# 37    â¹6,384.57
# 38    â¹6,548.44
# 39    â¹6,507.66
# 40    â¹6,544.00
# 41    â¹6,563.33
# 42    â¹6,741.68
# 43    â¹6,795.35
# 44    â¹6,786.87
# 45    â¹6,523.10
# 46    â¹6,498.43
# 47    â¹6,524.06
# 48    â¹6,593.10
# 49    â¹6,654.03
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# 8     82.910400
# 26    83.493401
# 6     83.009598
# 34    83.895103
# 4     82.927597
# 37    83.614700
# 24    83.601601
# 44    84.306396
# 33    83.940598
# 49    84.802002
# 15    83.544998
# 9     82.752296
# 16    83.301804
# 30    83.743896
# 36    83.934799
# 25    83.450897
# 11    83.226601
# 0     83.240601
# 46    84.488297
# 27    83.518501
# 31    83.988998
# 39    84.009399
# 29    83.744400
# 45    84.473801
# 1     83.076103
# 21    83.320900
# 2     83.160599
# 40    83.945999
# 35    83.983597
# 23    83.522102
# 48    84.666000
# 10    82.965599
# 22    83.473099
# 18    83.459396
# 52    85.786598
# 20    83.286400
# 7     82.872299
# 42    84.081802
# 14    83.349297
# 28    83.674301
# 51    85.386002
# 38    83.617104
# Name: USD_INR, dtype: float64

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((42,), (11,), (42,), (11,))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train.values.reshape(-1,1))
x_test_scaled=scaler.transform(x_test.values.reshape(-1,1))
print(x_train_scaled)
print(x_test_scaled)
# Out:
# [[-1.23184806]
#  [-0.32635194]
#  [-1.07777804]
#  [ 0.29755937]
#  [-1.20513879]
#  [-0.13795327]
#  [-0.15829924]
#  [ 0.93636577]
#  [ 0.36821923]
#  [ 1.70612339]
#  [-0.24621229]
#  [-1.47740975]
#  [-0.62393387]
#  [ 0.06270982]
#  [ 0.35921345]
#  [-0.3923667 ]
#  [-0.74073653]
#  [-0.7189923 ]
#  [ 1.21888673]
#  [-0.28736636]
#  [ 0.44339384]
#  [ 0.47507998]
#  [ 0.06349191]
#  [ 1.19637227]
#  [-0.97448406]
#  [-0.59427404]
#  [-0.84324845]
#  [ 0.37660884]
#  [ 0.43500424]
#  [-0.28177329]
#  [ 1.49489034]
#  [-1.14611536]
#  [-0.35788403]
#  [-0.37916612]
#  [ 3.23536494]
#  [-0.64785846]
#  [-1.29102556]
#  [ 0.5875338 ]
#  [-0.55016939]
#  [-0.04538328]
#  [ 2.61317185]
#  [-0.13422061]]
# [[-0.36254097]
#  [ 0.54404534]
#  [ 1.32559344]
#  [-0.48229421]
#  [ 0.60259479]
#  [-1.11551938]
#  [-0.46162829]
#  [ 1.92822264]
#  [-0.86576289]
#  [ 0.38018745]
#  [-0.3505846 ]]

# %%
x_train_scaled,x_test_scaled
# Out:
# (array([[-1.23184806],
#         [-0.32635194],
#         [-1.07777804],
#         [ 0.29755937],
#         [-1.20513879],
#         [-0.13795327],
#         [-0.15829924],
#         [ 0.93636577],
#         [ 0.36821923],
#         [ 1.70612339],
#         [-0.24621229],
#         [-1.47740975],
#         [-0.62393387],
#         [ 0.06270982],
#         [ 0.35921345],
#         [-0.3923667 ],
#         [-0.74073653],
#         [-0.7189923 ],
#         [ 1.21888673],
#         [-0.28736636],
#         [ 0.44339384],
#         [ 0.47507998],
#         [ 0.06349191],
#         [ 1.19637227],
#         [-0.97448406],
#         [-0.59427404],
#         [-0.84324845],
#         [ 0.37660884],
#         [ 0.43500424],
#         [-0.28177329],
#         [ 1.49489034],
#         [-1.14611536],
#         [-0.35788403],
#         [-0.37916612],
#         [ 3.23536494],
#         [-0.64785846],
#         [-1.29102556],
#         [ 0.5875338 ],
#         [-0.55016939],
#         [-0.04538328],
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-7ca038bcf6b6> in <cell line: 0>()
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor=LinearRegression()
# ----> 3 regressor.fit(x_train_scaled,y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,x_train_predict,color='red')
plt.title('Goldrate vs USDINR')
plt.xlabel('USDINR')
plt.ylabel('Goldrate')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a205336f73fe> in <cell line: 0>()
#       1 plt.scatter(x_train,y_train)
# ----> 2 plt.plot(x_train,x_train_predict,color='red')
#       3 plt.title('Goldrate vs USDINR')
#       4 plt.xlabel('USDINR')
#       5 plt.ylabel('Goldrate')
#
# NameError: name 'x_train_predict' is not defined
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pip i0nstall sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
regressor.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
)gold_dataset['Goldrate']= pd.to_numeric(gold_dataset['Goldrate'])
sns.regplot(x='USA_INR',y='Goldrate',data=gold_dataset)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "â¹5,066.31"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d06f2100b415> in <cell line: 0>()
# ----> 1 gold_dataset['Goldrate']= pd.to_numeric(gold_dataset['Goldrate'])
#       2 sns.regplot(x='USA_INR',y='Goldrate',data=gold_dataset)
#       3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     230         coerce_numeric = errors not in ("ignore", "raise")
#     231         try:
# --> 232             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233                 values,
# ...

# %%
usd_inr.head()
# Out:
#         Date     USDINR
# 0 2024-01-01  83.240601
# 1 2024-01-08  83.076103
# 2 2024-01-15  83.160599
# 3 2024-01-22  83.146103
# 4 2024-01-29  82.927597
